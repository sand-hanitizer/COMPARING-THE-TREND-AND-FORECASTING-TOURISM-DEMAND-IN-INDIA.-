# %% [markdown]
# #Team-7: Mini Project
# ##Team members:
#
# Dharshni.S (2020PITAIDS103) -211520243012
#
# Mamatha.J (2020PITAIDS109) - 211520243031
#
# ##Team Guide:
#
# Dr.T. Kalaichelvi , M.E., Ph.D., HOD, AI&DS.

# %%
import csv
import pandas as pd
import warnings
import numpy as np
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('Country Quater Wise Visitors (1).csv')

# %%
#Train and test data:

X = df[['x', 'y']]
y = df['T/F']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=27)
norm = MinMaxScaler().fit(X_train)

# %%
#Standardising data

scaler=StandardScaler()
scaler.fit(X_train)
StandardScaler(copy=True,with_mean=True,with_std=True)
X_train_standardized=scaler.transform(X_train)
X_test_standardized=scaler.transform(X_test)

# %%
#Creating classifier

classifier=svm.SVC(kernel='linear')
classifier.fit(X_train,y_train)
x_train_pred=classifier.predict(X_train)
TrDaccuracy=accuracy_score(x_train_pred,y_train)
x_test_pred=classifier.predict(X_test)
TeDaccuracy=accuracy_score(x_test_pred,y_test)

# %%
#Calculating accuracy and prediction


print("Accuracy of the trained data is ",TrDaccuracy)
print("Accuracy of the tested data is ",TeDaccuracy)
input_data=( 7, 7.2)
input_data_as_ndarray=np.asarray(input_data)
input_data_reshaped=input_data_as_ndarray.reshape(1,-1)
std_data=scaler.transform(input_data_reshaped)
print(std_data)

prediction=classifier.predict(std_data)
if(prediction[0]==True):
    print("The tourism had met with a positive impact after the lockdown")
else:
    print("The tourism had met with a considerable loss after the lockdown")
# Out:
# Accuracy of the trained data is  0.8
# Accuracy of the tested data is  0.6153846153846154
# [[-1018.66959855 -1258.65007051]]
# The tourism had met with a considerable loss after the lockdown
